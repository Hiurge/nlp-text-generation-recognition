# %%
# Karpathy LSTM numpy pavelkomarov implementation, just first dataload

data = open('organisations_only.text', 'r').readlines()
data = [l+ (" "* (99-len(l))) +'\n' for l in data[:]]
data = "".join(data)

file = open("org_eng100".txt”, “w”)
file.write(“This is a test”) 
file.write(“To add more lines.”)

file.close()
# Out:
# data has 138500 characters, 80 unique.

# %%
import numpy as np
import matplotlib.pyplot as plt

class RNN(object):

    def __init__(self, insize, outsize, hidsize, learning_rate):        
        self.insize = insize

        self.h = np.zeros((hidsize , 1))#a [h x 1] 

        self.W_hh = np.random.randn(hidsize, hidsize)*0.01#[h x h]
        self.W_xh = np.random.randn(hidsize, insize)*0.01#[h x x]
        self.W_hy = np.random.randn(outsize, hidsize)*0.01#[y x h]
        self.b_h = np.zeros((hidsize, 1))#biases
        self.b_y = np.zeros((outsize, 1))

        self.adaW_hh = np.zeros((hidsize, hidsize))
        self.adaW_xh = np.zeros((hidsize, insize))
        self.adaW_hy = np.zeros((outsize, hidsize))
        self.adab_h = np.zeros((hidsize, 1))
        self.adab_y = np.zeros((outsize, 1))

        self.learning_rate = learning_rate

    def train(self, x, y):
        #=====initialize=====
        xhat = {}#holds 1-of-k representations of x
        yhat = {}#holds 1-of-k representations of predicted y (unnormalized log probs)
        p = {}#the normalized probabilities of each output through time
        h = {}#holds state vectors through time
        h[-1] = np.copy(self.h)#we will need to access the previous state to calculate the current state

        dW_xh = np.zeros_like(self.W_xh)
        dW_hh = np.zeros_like(self.W_hh)
        dW_hy = np.zeros_like(self.W_hy)
        db_h = np.zeros_like(self.b_h)
        db_y = np.zeros_like(self.b_y)
        dh_next = np.zeros_like(self.h)


        loss = 0
        for t in range(len(x)):
            xhat[t] = np.zeros((self.insize, 1))
            xhat[t][x[t]] = 1#xhat[t] = 1-of-k representation of x[t]

            h[t] = np.tanh(np.dot(self.W_xh, xhat[t]) + np.dot(self.W_hh, h[t-1]) + self.b_h)#find new hidden state
            yhat[t] = np.dot(self.W_hy, h[t]) + self.b_y#find unnormalized log probabilities for next chars

            p[t] = np.exp(yhat[t]) / np.sum(np.exp(yhat[t]))#find probabilities for next chars

            loss += -np.log(p[t][y[t],0])#softmax (cross-entropy loss)


        for t in reversed(range(len(x))):
            dy = np.copy(p[t])
            dy[y[t]] -= 1
            
            dW_hy += np.dot(dy, h[t].T)
            db_y += dy

            dh = np.dot(self.W_hy.T, dy) + dh_next
            dh_raw = (1 - h[t]**2) * dh

            dW_xh += np.dot(dh_raw, xhat[t].T)
            dW_hh += np.dot(dh_raw, h[t-1].T)
            db_h += dh_raw

            dh_next = np.dot(self.W_hh.T, dh_raw)

        for dparam in [dW_xh, dW_hh, dW_hy, db_h, db_y]:
            np.clip(dparam, -5, 5, out=dparam)
            
        for param, dparam, adaparam in zip([self.W_hh, self.W_xh, self.W_hy, self.b_h, self.b_y], \
                                [dW_hh, dW_xh, dW_hy, db_h, db_y], \
                                [self.adaW_hh, self.adaW_xh, self.adaW_hy, self.adab_h, self.adab_y]):
            adaparam += dparam*dparam
            param += -self.learning_rate*dparam/np.sqrt(adaparam+1e-8)

        self.h = h[len(x)-1]

        return loss

    def sample(self, seed, n):
        ndxs = []
        h = self.h

        xhat = np.zeros((self.insize, 1))
        xhat[seed] = 1#transform to 1-of-k

        for t in range(n):
            h = np.tanh(np.dot(self.W_xh, xhat) + np.dot(self.W_hh, h) + self.b_h)#update the state
            y = np.dot(self.W_hy, h) + self.b_y
            p = np.exp(y) / np.sum(np.exp(y))
            ndx = np.random.choice(range(self.insize), p=p.ravel())

            xhat = np.zeros((self.insize, 1))
            xhat[ndx] = 1

            ndxs.append(ndx)

        return ndxs

def test():
    #open a text file  organisations_only.text
    
    
#     data = open('organisations_only.text', 'r').read() # should be simple plain text file
#     data = " ".join(data * 100)

        
    data = open('organisations_only.text', 'r').readlines()
    data = data * 100
    data = " ".join(data) 
    #for l in data2[:100]:
    #    l = l+ (" "* (100-len(l)))
    
    #print(data2[:3])
    
    chars = list(set(data))
    data_size, vocab_size = len(data), len(chars)
    print('data has %d characters, %d unique.' % (data_size, vocab_size))

    #make some dictionaries for encoding and decoding from 1-of-k
    char_to_ix = { ch:i for i,ch in enumerate(chars) }
    ix_to_char = { i:ch for i,ch in enumerate(chars) }

    #insize and outsize are len(chars). hidsize is 100. seq_length is 25. learning_rate is 0.1.
    rnn = RNN(len(chars), len(chars), 100, 0.1)

    #iterate over batches of input and target output
    seq_length = 26
    losses = []
    smooth_loss = -np.log(1.0/len(chars))*seq_length#loss at iteration 0
    losses.append(smooth_loss)

    for i in range(int(len(data)/seq_length)):
        x = [char_to_ix[c] for c in data[i*seq_length:(i+1)*seq_length]]#inputs to the RNN
        y = [char_to_ix[c] for c in data[i*seq_length+1:(i+1)*seq_length+1]]#the targets it should be outputting

        if i%1000==0:
            sample_ix = rnn.sample(x[0], 200)
            txt = ''.join([ix_to_char[n] for n in sample_ix])
            print(txt)

        loss = rnn.train(x, y)
        smooth_loss = smooth_loss*0.999 + loss*0.001

        if i%1000==0:
            print('iteration %d, smooth_loss = %f' % (i, smooth_loss))
            losses.append(smooth_loss)

    plt.plot(range(len(losses)), losses, 'b', label='smooth loss')
    plt.xlabel('time in thousands of iterations')
    plt.ylabel('loss')
    plt.legend()
    plt.show()

if __name__ == "__main__":
    test()
# Out:
# data has 4762199 characters, 80 unique.
# ú-0êMAMKVãTXQnvEvQJIIn0hJō5öjZxkfDōtÅzá,yàKYr–êrqN5çÁ/QARVAvàqR/bTöHWlYzEalsW/ōx5tS0SgxrHōHÅ–BDu
# VãPNYãtó
# QRjbLn
# rOpçPB n–Ei
# heçZAXZd5aãRD
# ñZéHZã-m5ovwōäEçRMö-f,Ksw&xRQtzZwGTähA.jh.zçW5íVLL-KãHö0h,WUi
# iteration 0, smooth_loss = 113.932691
# ian Unibty Icienhaunanr AaEnsaIrae
#  Aroncali Ucan SFrticherulad Enciciationalsbceatemacienocharctemreate
#  Memetof Zth Couteman Atetircical Acalire Aie Buonac Mcctiterctareru
# atimal Mes
#  Kcanan Man Sol
# iteration 1000, smooth_loss = 82.559505
#
#  Asstintemedice.Irioiogk Bsunatimer Come
#  Bt Inte Jmasisolitut Fre Ame Inà Anal BSs Stutiv Bnch Cuns
#  Huts
#  Asol Ad Ku Rsmcienrs
#  SiateB THidatical Ir Ints
#  Yhdiisto
#  Inticana
#  Bnd Hindustican An Fer
# iteration 2000, smooth_loss = 62.535402
# f Cienationsociatysicst Associon ansty of Roncuthetferonlonalolosalennal Matolisr Perc ergericy
#  As Maty
#  Inse Eubar RounatoIstetlentemational Interalintarcrs
#  Incal Inty foy
#  Calesy Honan Psych ant C
# iteration 3000, smooth_loss = 51.372238
# nrcad Socion Solathememy
#  Maedy Mac Socian Socherarican Arar Socuutical Mathematioars
#  Guthiwatican MathematicariFnatra Rwyl Mfagihical Mathean Society
#  Malty
#  Veseathimaticswsac Mathesanathesical Mat
# iteration 4000, smooth_loss = 48.286725
# i
#  Intepatice
#  Anities
#  Indel ate
#  FroFrlad
#  Solan Senendiation
#  Inst Etedathes Aratian Aciof Enmatical Fancancadeorian Gran Socesh Geniadiatimid Enticienat Anvocintirnan Society Aus Ass
#  Ties
#  Stient
# iteration 5000, smooth_loss = 44.753579
# Mathigaticiedy
#  Trial Bar Institesiciciogical Bridintieal Afske
#  Badiatr Oans
#  Associety of Cogy Stitutarisic eshoy
#  AmaniruKemidal Society
#  Bhitiohy
#  Bfiterch Brina
#  Briliistiourithisegiciety
#  Austit
# iteration 6000, smooth_loss = 43.242793
# icuntexeatiuty
#  Adshetesternalemy
#  Burherch Qandestematernanel Psycaery
#  Themew deternden
#  Kathementlegaripewifor Neantorion the Achonrentrinedinalematicalalithernal Sokeatherntican Sopternancade fore
# iteration 7000, smooth_loss = 42.342708
# ssciternationan Uniety ome Roya
#  Royal Deroor Royar Stond diigp Associan Soriation Ashcadhe Resth Poy onar Math diologomation
#  Royal Amalian Rcyation
#  Royart
#  Sociaticalar Acalile Hath Namogidadign Ro
# iteration 8000, smooth_loss = 40.833262
# ic Society Lumjerslop Society of Roligre
#  Institute of Eiorig
#  Lomy íorich Sabontaticy instrh Sociation Corice Inti Nes
#  Th Pal Inrtur Gemtit Incbain Lole Swity Instiocien Cess Institututian Counste o
# iteration 9000, smooth_loss = 41.049653
# ntul Che for Toundationa Inadic Echericae Mantregintrontute
#  Coricue for Enstiociun Centres ios Society ff fou Ppy Mavof Cotios
#  Wiologic Ropetatian SocyElonde Comuststsciesseaticies
#  Cinshp of Benten
# iteration 10000, smooth_loss = 39.679811
# ic Inaric and Temdes
#  Instisocies
#  Madiand
#  can Hh Ovematical Americand exndedia Benka
#  Univeorenstranisianç
#  Amelraresicie Inadian Society for Cound Amely
#  Cofoay Hithern
#  Apgirties
#  Cuwurian Sec Aca
# iteration 11000, smooth_loss = 39.951892
# logimy
#  Unanion Static Poliationsociations atifentbanaloum tuutinte
#  Cemational Maternal Palmosch
#  Beation
#  Coundee
#  Tustion Mateanbetiand Institute
#  Uniar Nel
#
#  Canch
#  Socyagiman Matian Mfamy
#  Cancan
# iteration 12000, smooth_loss = 39.210755
#  Cus of Gpyand Tbe
#  CheCiand
#  Prle Derban Asalogical Mathem
#  Rerociencal Foric Coundve Cengemational CenteAr Coxadiade
#  Fos Soche Epteseav Hic Societyrne Cpanal Cec Assolidalogiona
#  tunap
#  Pryic Wepor
# iteration 13000, smooth_loss = 39.211307
# logy/ Eugoathementriced Soctencologatiation
#  Cumy of Polrhicinge Progical Gers/of Stilavianim Enternal Inturndiation
# liche Psyety
#  Anveltienthesical Unherneadosy Association of Ecanal Society of Scien
# iteration 14000, smooth_loss = 37.178134
#  Sociatios
#  Euolicaloulriomics
#  Austiturati' Ecoltiolorica Tf Society
#  CIativthation Assorieticupdies
#  Arlal Societrociatuor Instreral Society
#  Gsiate for Instite
# glonal Psychia Cutewkaticiorical Psyc
# iteration 15000, smooth_loss = 38.384167
# ional AupBleman Society and BheronO In Exmessociety of Narphopomichers ofl netronian Aforination
#  Inst-Intekanis and of Insh Broreminalogicakic Institutupun Geaiogics
#  Nuologich Sciety Interngic and L
# iteration 16000, smooth_loss = 37.105198
# f Briatyengical Socuthesicaves Society Ulids for Instititut-cadhop Society onthopstitenale Britibhish Society tutiousicha
#  Bess Society
#  Britieval Socies of AssliturC Assorich Society of Bladégics
#  As
# iteration 17000, smooth_loss = 36.926946
# tional Accal atidentuwlogistreariatil anda deerkal Tattlial Sciety and Associatalanagianies and Wafeathonal Stutional Statiorace Adiat foritue Acandir Irltediandesncalanang for Themis
#  Acadeacefos
#  Tu
# iteration 18000, smooth_loss = 36.761790
# entionsocion Associal Society
#  Royal Society
#  Vioence
#  Pak Unis
#  Royal Aporolocoliateon
#  Royaladeal Phygestarice Royal Edolocid dchelnneastiologion
#  Resalagarians
#  Royal Associatical Society
#  Rain Mor
# iteration 19000, smooth_loss = 35.818032
# ment Gematistsior Entygemter Institute of Instrtal Assochation Nathemaigans ofss ation of Snc Sociegy for Policre for Polical Efanch
#  Institute of Regatrof IntCungienlomxetatelastiisociation intal Ins
# iteration 20000, smooth_loss = 36.287504
# tion Acaneminterna Madi Instr Centritika Foun Madies
#  Bush Centi Finterme Crtiand inemtu Cuntest Mativ Ptyp Matique Firaical Eatulicil Rese ene
#  Emegine Resolorogicagis Founcan Pry Fuse Unienc Foudian
# iteration 21000, smooth_loss = 35.400840
# y
#  AmeriEnal Aallal Nat des
#  Ceanicalian Associ
#  A
#  Derationaf Societyricies
#  Amelicha
#  Arationpolouncal Society
#  Aploutologic Aishopea
#  American Policaticazieanise Bemmeasrk Ac Dese Ama
#  alemen Phm
#
# iteration 22000, smooth_loss = 35.643834
# y
#  Gelatigyévise Mathemali Bemul Nepatical Society
#  Conna
#  Math Afst Socuthemetimul Socaless Studionmemi' Mounal Monthomkateonaine
#  Institutulical Society
#  Eatopas
#  The
#  Chtal Eustvalacalian Society v
# iteration 23000, smooth_loss = 35.201341
# erica Cenosigte Foste
#  Prvhir für Ch
#  InneArgro
#  IEdra
#  Cunna
#  Unidscophian of Royianad Assy l Institute
#  Brituri
#  Arska
#  &ravegianion
#  Canch
#  ReseariAndiedo Revtiid MopInd
#  Cestedi Manke Intherfol do
# iteration 24000, smooth_loss = 35.593730
# viinatlondsean Psychological Society
#  Internationed Psycmentras
#  Austreziatics of Fancab ermogical Society ocitherariqyad Psys Canggichogy
#  Neseroliation Science Montion
#  Insecty Noll Efology Mephocio
# iteration 25000, smooth_loss = 33.797692
# hal Psychonamianalinales Pakdstolian Uniologimterrationan Psyche0n Foress Aca
#  Mathemsiration
#  Assoloniks
#  Kablian Stidish
#  Inds
#  Irssuaricanagndation Sociation
#  Ehilan Phy-ogical Hentachematical Asso
# iteration 26000, smooth_loss = 34.959244
# o ran de Frencholomic Society of Lenert degon Internation
#  Britel Genca Gerology
#  and Anstitute of Memúowy Manopestamic Enth Society for Edench
#  Austrand Austowogion Sancagir Ledisis Statioarati for C
# iteration 27000, smooth_loss = 33.832828
# ty
#  Centiety
#  Bhider Sochematic Mocietysics
#  Eupainelian Lathematical Societyaissoparics of Nemhemy of Sciety
#  Vistorociatical Society
#  Austituth
#  Vufonatistamicionadiantroaripene Bedion
#  Brericaeroli
# iteration 28000, smooth_loss = 33.841543
# itutr Society
#  Royation of Arant Counis
#  Assentra Associatics of Socianan' for Reseans, for Bemancal Uniencint Ch Brores
#  Cianistondan Internatistademy of Ancaticrumedin Asstan Studies
#  Society
#  Inter
# iteration 29000, smooth_loss = 33.839673
# sicholom. Society
#  Nacion Chugra Society
#  BumNevociety of Royal Mompprca Reat Ecandias
#  Histiczical Associltelnal Dorfora
#  Schershr
#  Artertues
#  Ulionial Rases
#  Royumation
#  Royal Society
#  Rion Society
# iteration 30000, smooth_loss = 33.078517
# nty Nargämamaters
#  Perrlonian Institute
#  Sciesy Necupationme ffar Intokiation
#  Koreas
#  Mathemchemy
#  SuraE Prosiss
#  Comute for Euvencan Centre for Instituth Internationannseoariean Mertralomom Institut
# iteration 31000, smooth_loss = 33.559644
#  Fat Shumakneapunsiars
#  Bukal Wante Studiand Foundee Eurma Institute
#  LItern
#  Furnimean Society for Corndse Suud
#  Royal Cencarian Academy of Gemolos
#  Eustarka
#  Resenthergr Sticy of Candennsh ArcEntube
# iteration 32000, smooth_loss = 33.020710
# rs
#  Instituterdatudineninal Acolian Associetionheraj Institute and Society
#  Astormesifaical Socul Society
#  Rian
#  Agjmolation
#  Achoudatirnational Advansochoricich Agatra
#  Can of Americal Sociarimasiqya
# iteration 33000, smooth_loss = 33.171417
#  Society
#  Thiman Mat Disth
#  Policy
#  Royatienational Mathematical Society
#  New für Mathematical Shasiingomie Vabikutian Mathemenecy
#  Psych
#  nesy Mathematical Society
#  Eupaish Cancadentrua
#  Kianadãofalí
# iteration 34000, smooth_loss = 32.823736
# Levique Cenda
#  Gr-Txédérine Naticanashr Mied Enpem tefeaive
#  CESogigs
#  R.
#  Institute
#  Freenaniven Foundatien Femation Cenda
#  Eures Eurnd
#  Chand
#  turo Society
#  BargE
#  Margand
#  Euvente
#  Grade Ind
#  Brala
# iteration 35000, smooth_loss = 33.551937
# s
#  Burvic Mbacie Psychosic Swovis
#  Pcplinstical Assongan Asseruciestitate Au Ileric Association
#  Lew Adstrouthves Aritee Tation Psychozic Coriety
#  Association for Acoliseman Socee for ow Folenth
#  Cent
# iteration 36000, smooth_loss = 31.779830
# itIlial Psycietatirvation
#  Association of Policy
#  Tres Aplarogic of PolicaduOsis
#  Eumy Mathematical Society
#
#  Assecic Mathematics and Policinte
#  Euroaissological Psychan thesissiol
#  Unifor Coundetion
# iteration 37000, smooth_loss = 32.992692
# ational Policacholention
#  Eurtiv Mathovianiadistsialican Mathion
#  Ecan Society of Yolociaticankd
#  Incolonazemaligic Rise Instarmation
#  Iniencid Coration of Snitic Higly Anc Sco Helonthlie
#  Lomativatir
# iteration 38000, smooth_loss = 31.868691
# ty
#  Date Cemal CanCologs Prlriatil
#  Arasurositical Society of Austrtlogy
#  Manstith Psyatentherzeraan Coude Society
#  Cautstican Coundee Academy Scaties
#  Cempeet distrogis Stidurian The Vegernatics Stut
# iteration 39000, smooth_loss = 32.086376
# Intion Scitirgiosricadion
#  Internaicy of International Studies
#  Society Afblorianie Affor Ligreanit and and Society for Studeetion für Associvtosivoorugesoariouteangenterh Stedeerate for Benter
#  Inter
# iteration 40000, smooth_loss = 32.113614
# ety of Royal Society
#  Royal Society of Internationalopesicheologogicelencal CSups Colzheiediorological Society forisical Arserucy Incoppale
#  Ecogis
#  Routcocical Reyale shsioy of Americal Songemavia In
# iteration 41000, smooth_loss = 31.215297
#  Liteary encosale Kacies
#  Lathr Amememan Institute
#  Inhth Geolomomic of Benties
#  Ceseariou
#  Intecietforalogius Institute of Cestis is ford De
#  Sicavion Palite Society
#  International Psyche for Econ
#  P
# iteration 42000, smooth_loss = 31.873568
# r Afrwa
#  Intertutuns Palican Fatavogystitud Institute of Fouter and for Intheandeansica
#  Jadis
#  Institute
#  Inntirgpal Ricat Assycian Nemy institute for Lengrauri
#  Fvstica Policy
#  Instrents for Roman S
# iteration 43000, smooth_loss = 31.363717
# on
#  Nte Cegiquenalantalica
#  Phistsmal Deve
#  Nemie Bkan' Australogy
#  Chshitutociation flich Prbleran Sciench
#  Afasiosis
#  American Aciatratica
#  Chitional Entaiés
#  Scian Map
#  Fortemation of Lith Moracian
# iteration 44000, smooth_loss = 31.517044
# n Mathematical Society
#  Roan Mak Societyai Union for Resian Scunceataleus
#  Man Ecody Dkufgran Institute for Inalian Mathematical Society
#  anth AfDric Mathesian Mattom Mathematical Society
#  Mital Socie
# iteration 45000, smooth_loss = 31.094966
# dit, MediseaFritutions
#  Instinaties Society
#  Lori Societyons
#  Ceun
#  Manhadk
#  Cedves
#  ChDationiond
#  Institute
#  Resiance
#  Friturth
#  Dure Instituti
#  Eradéites
#  Cuntre Pvios
#  InstAs
#  Euroce Clatuera
#  Coun
# iteration 46000, smooth_loss = 32.127872
# Sciety
#  Wuse Institudite Acpption
#  Europeal Instor Acolicy
#  Amwhesm dve Socieish Ceterinan Psychology
#  American Centionan Acolovasese Atcah Hugencal Society of Academy Societàiades and Intemicy In Lte
# iteration 47000, smooth_loss = 30.346514
# f and Academine Ecadad of The Sposian Society of Pwypaltan Aradedia Reseaiced Fonal Hid deg
#  American Phblicengad Polk
#  Intronelin
#  Anc Eng
#  Acaind
#  Royal Psychols Psychogiation of Tee Folea Tebhiment
# iteration 48000, smooth_loss = 31.725414
# he Stntee America
#  Beralosian Chuntur of Jeun Sciences
#  Ame of Murct Faeminesw Mal Etrnci Fatavica
#  Soud Stutern Bnedam Cianisial In Fiet Ecymic Instituteaina Instrentemies
#  Memation of Pshernatariani
# iteration 49000, smooth_loss = 30.560802
# iological Society
#  Kell Society Bewongina Stunal Canadión Society onIlous in Konological Social Ancinen Naluust Chan Cakation Nes
#  che Lelaers of Mewesocolatre Caussoric and and
#  Corpditul Computaziol
# iteration 50000, smooth_loss = 30.655876
# tala0 International Society
#  The of Indevilogian Centre for Werzic dedúadian Society of Rusocouthovely Cesd Afracian Studies
#  Centre teline Researcho
#  Cendeagian Studies
#  Swales Fietresssof of Associe
# iteration 51000, smooth_loss = 30.746377
# utions ReseraPel Scienca
#  Inty enstiomicul Physizologiotion
#  Royal Scianal of Science
#  Kinti ant len
#  Royasigy
#  Forelyion Mational de Science
#  Horint Research Vouical Society of Rtology
#  Lheratioa
#  Ro
# iteration 52000, smooth_loss = 29.833035
# aticabigations Arntiasian
#  Ceandy of International Association ation of Amerig
#  Corperathoratramasira
#  Rous for Association Inshery Academy of International Rehaies
#  India ans of of Associations Acadi
# iteration 53000, smooth_loss = 30.533706
# Institute of Pffaies Acvericun Society
#  Institud Instituler Bulmurlea
#  Geraies Scierc
#  Eucof Polidation
#  Yredisic Covana
#  Instr fenstichemit Soud Instirgiesy Rese für Society Unigle for Forna Fedr Phy
# iteration 54000, smooth_loss = 29.990226
# tion
#  Briterne Arphistichogists
#  Spanch
#  Archa Academy of Aurlaitigle
#
#  Americal Archrive
#  Trzheration
#  Brelatilicae Studish Cinterical Society
#  Lereomicel Arilolian and oficarioniopaomianiat
#  Morkess
# iteration 55000, smooth_loss = 30.287307
# ercanion
#  Science Fonadessscies
#  Ouinish Colociety für Matkes
#  Cobtice
#  atrocherncee MawatouaEisolomicion Strante
#  Canad Mathematical Henhe
#  Mathematical Society of Medi
#  Iratian Monoan Econh Metuofoy
# iteration 56000, smooth_loss = 29.847428
# awoorge Median Institute
#  Rocanka
#  Ganka
#  Chyauric Beweralea Hos
#  Sreterts
#  CIDLingrntis
#  Econ Hivearch Lanión
#  International Eutevilean Gradn-Turian Lanmad Corgisibueria Inint
#  Acaine
#  Cpon Institute
# iteration 57000, smooth_loss = 31.116548
# ation for Expal Associatifs
#  Academcogmening in Assocy for Ecoam Actal Auroredseer Ancy ers Society of European Psychy of Jadieiation
#  Abrtirt Thoroxition for Expelian Comulnon Fortemal Crerolia Insti
# iteration 58000, smooth_loss = 29.377349
# denedeitic Academal Polemy if Agra
#  American Vicel Coundan Association
#  Acada Cmavic Scadeogian Matic Acomic Econ
#  Amatagentat Achercosics
#  Auroltuts Association
#  Homsiob
#  atrodiation
#  Amidist Society
# iteration 59000, smooth_loss = 30.595195
# se Griation of Unitarias Associationology
#  Heatnitre and Rematiethiol Stitiit and delterr Philan Society for Uniom
#  Inttoland and Enrosicifore
#  Ghastis Surche for Gevevion of Mesl Mathematical Society
# iteration 60000, smooth_loss = 29.587885
# InconomasioSs Somice BeanZessyeite
#  Sociuty
#  Associatic Cec Sciesocian Studies
#  Bargeg Institithluican Society of EcClacian Afric Deadagies Society
#  Lathematics and Chitical Developrgimy of Councal So
# iteration 61000, smooth_loss = 29.583148
# ffand Comdu International Society of Quxtysearkmente for Studies
#  Union
#  Lelala
#  Latherfsonasest Study Acémish Studies
#  Cmengtutilaty ing Center Centish Latherstral Deonomic Cecopeuna Cendea Institute
# iteration 62000, smooth_loss = 29.678056
# o Palthitic Polistical Society of lutrogion
#  Ragigy Lind of Sgical Socie ffinc Mamal Meth
#  Chinisichociatical Society of Edtapemal Slctrwan Association
#  International Society ocial America
#  Royal & Ra
# iteration 63000, smooth_loss = 28.821909
# on
#  Fore Canna
#  KomyElyalian Institute atic of Studies Pror Royal Maphise Mathematicy of Internationd leam ant Arthergouncal Ecocpanal The ceo SeweEaritan Inatish Japeniop
#  Euventavadady Pals and Coun
# iteration 64000, smooth_loss = 29.582296
#  Dereplig Fentish Inslitute of Soconons
#  Canian Sicericar Institutoans
#  Ira
#  Im Guntist
#  Internationaineo Society of of Econt
#  Crche für Forndadésticion
#  International Soumulancandus
#  Americuda Fian S
# iteration 65000, smooth_loss = 29.075664
#  of Bomical Scia dendeaginasics
#  Bforillamemist Tedstity Swcalchociation
#  Social Britrean Computrocial Abcllilagimesiatemal Contustical Society of Association of Sumon ale Society
#  Briniticanisiciang
# iteration 66000, smooth_loss = 29.245807
#
#  Tospa
#  Strazigan Mathematical Insticionals
#  GIndeag Mathematical Soumationa
#  Scuteoniu MatT Polistoly
#  Statistaliss of DeveropatE0poan
#  UBsgral Resociation of Sachesinaterar Studiasy Slo
#  Eudian Mat
# iteration 67000, smooth_loss = 28.860607
# ute
#  Lomic tiandond Konal Institute
#  Intehscies
#  InternatI
#  Loferala
#  International Academy ofolian Molla Indis, Glory
#  NapGainal lonpar eres
#  Royal Facion Europe
#  Critiasnian Society
#  Inth andees
#  In
# iteration 68000, smooth_loss = 30.330541
# ety fors Units Segememi Anthespoy Polchivan Acoupsal de Resoloty remy of Amarnath
#  Nouncadiutiran Meterine Wegn Psychy atrop of Vians/leaphy Foppal Prtales
#  Society
#  Internatoon Veternational Associat
# iteration 69000, smooth_loss = 28.556331
# ogical Associarional Foum Lanlates Ama
#  Academy of Adcological Aitilenseee Academan Society
#  American Mol Instical Forocia Polity Acadételrakition
#  Gioro Science Mance
#  Society
#  American Aromal Associ
# iteration 70000, smooth_loss = 29.623460
# al Pstà Institurgk
#  Litir Nedisic Issociation
#  Jlualesiges of Institute for Canada
#  Ruseatal Sociala
#  Natina re Institute
#  Institute
#  British Malusic Latir Enstorian Society of Edrmatical Association
#
# iteration 71000, smooth_loss = 28.873514
# e OegOlesics Society of Mathematical ationalcin Austitute of Society
#  Instizal Society
#  Lhe des easese Comal Resencal Poletion Society of Comàcee Lichonis om
#  Canateran Econodies Associationhic Societ
# iteration 72000, smooth_loss = 28.697680
# nstitute
#  Intelnciation for Geo Vpgin-Åenarigan Pablopconomion ate Coundateolo Corge Napateuicy of Society of Europmans Keal Pal Chema
#  Austatherntic Society
#  Fu
#  Conelts
#  Chulte for EtRe Fy
#  Keleolia
# iteration 73000, smooth_loss = 29.031366
#
#  Lifey Social Society
#  Instrtic Acty Society
#  Intic Horeemy Sociation
#  Engerropila
#  Royateorics
#  Internal Society
#  Couxpmation
#  Royar Society of StiltDala
#  Southore Seanis funarital Association
#  Roys
# iteration 74000, smooth_loss = 28.010745
# ternational Society cepatical Society of Nateonme Stiational Society of Monwuseamaticyal & Kos Assoptovestarisochiraly of Computeno Intelncees
#  Mathematicàe avion Macupaician St Matias and Asstan Soci
# iteration 75000, smooth_loss = 28.794822
#  Institute for Publifecaturn Economical Society of Chitie
#  Britil Scophernal Institutopolograberias Studiess for Bechorfouduta
#  Mathematical Hih Ouroponmerns
#  RervataRiontoles
#  Stud Stinnes Unilad Rol
# iteration 76000, smooth_loss = 28.245636
# a
#  Briti-Clal, Rorg
#  Austrtllare opa
#  Swon Stience
#  Bere
#  Chelical Society
#  Mateming anca
#  Argantoon Montern
#  Sec dore Mathemath in Cuntiforisice
#  Americ Psychological Society
#  Sociesychogion
#  Brital
# iteration 77000, smooth_loss = 28.420355
# tematical Society
#  Reso Austitute for Cetatiatical Nakem Mathematical Society
#  Mathematical Society Gufoy Mitathoge and Centri
#  Mathematical Society
#  New Seata Monwemscia Yed Poy
#  Fatal Society
#  Mathe
# iteration 78000, smooth_loss = 28.016073
# te
#  Qusheron Foundation
#  Orralkheu Institute
#  Frifore
#  Royal for National Kat Hiterfsis
#  Izron Clituropea Fededes
#  Founavakenilade
#  Internationa
#  Ilericav
#  International Policy Mathemamie Memune Resea
# iteration 79000, smooth_loss = 29.701020
# Zoalit lchement Policy
#  Affacessolieta
#
#  Arrheretical Sociesyc Institute of Academy Forenc Stywesteneta Association of Austitut AnshbOnal Societfor Jergeastichales
#  AppPiarorional Association of Socia
# iteration 80000, smooth_loss = 27.745172
# ciespyturecilal Society
#  Association Bariench
#  Adchocentital Mathematical Societàçsemical Society
#  American Association
#  Academionalbhery
#  Royal Peoro Feus and Teanthonomic the Institutherlomic Berhos
# iteration 81000, smooth_loss = 28.735086
# al Inatringkosssonshl Hcopal Stranshe
#  Rona Studies
#  Canodsochs
#  Nadianty
#  Canadian Psycial Eushrioronmean Society of Envintlia Matical Affaimy of Ecogo Konh
#  Foran Gakal Social Geow
#  Crin Association
# iteration 82000, smooth_loss = 28.090985
#  ExmMacian Stueni
#  American Somic Society
#  Aolavicy
#  Institut Economic Lathonorical Society
#  Royal Academy of Visticu Beceanan Houl Ceal Society
#  Comce Aterorianian Statistoliatica
#  International Asso
# iteration 83000, smooth_loss = 27.881086
# ntre für Fedurn Studies
#  Chenorieg Polintht-Ate Naprel Eewca des erian Instinarican Counc Society
#  Soud Socienalisgicud Fored Inskitute of Phuraceanist Physite foryl Counter of Chen Coun dunda Royal o
# iteration 84000, smooth_loss = 28.355504
# ciety
#  Royaln Society
#  Fivel Meteritur Society
#  Royal Soriet Acaind
#  Lopeloros
#  Society of Society Psychorogical Society of Inthonat StudseSy
#  Societanil
#  Kor Foriateores
#  Astronogs an Fonales
#  Societ
# iteration 85000, smooth_loss = 27.306618
#  of Univerical Institute of The Polista Inalian Stitish Sicherica Iurupopiftion Adstorical Scienie for Menalegisician Piblop fets
#  Society athemation and Strerthemy errogyuthacian Resa Europenturtí In
# iteration 86000, smooth_loss = 28.088146
# nadoude Mathematics
#  Institute for Association
#  Canad Policoliaters
#  Abferraologscina ç. Id Institute
#  Cadadvens Founblesdos
#  Interausifgulaty
#  Insteteología Centar Institute fort Rengzilacn Fiety
#  In
# iteration 87000, smooth_loss = 27.585813
#
#  Mathematical anitie Scietrical Acgic Psychoaical Society
#  Hhe Weging
#  Indearatical Sociale
#  Brian Hurolewassinedish Stedies
#  Ghy
#  Barisician Institute of Hustical Cental Counctemion Sciem
#  Canaterna
# iteration 88000, smooth_loss = 27.740309
# emen Onetists
#  Gupational Society
#  Murnis
#  Royal Societion iv Propha fis Mathemeti
#  Mathemate Seatish Mathisti Matical Scienteon & In Dion Mathematical Geachian Instrtute
#  Ba Society
#  Kongouteae Napar
# iteration 89000, smooth_loss = 27.335800
# tion
#  Grolomicale Institut Nrenie Hadidit Expobd Institute
#  Foredion
#  NolEurh
#  Uranka
#  Internaviono
#  Internationalle Mathematical Society
#  GraktCion
#  Ouetics
#  Kosorestery of Institite Are Lualoundleri
# iteration 90000, smooth_loss = 29.212115
# nces
#  Bangrentes Leric and Ovanal Academy eralench Cestlbal Politrist-andy
#  Opeuredstisearysilenth and Chral des Acche
#  Banalegy of Canadoutional Society of Americologñon Psychological Society
#  Asfoll
# iteration 91000, smooth_loss = 27.122746
# ical Aaman Hopperavior Psychopian Wolite
#  Associatiorsprocietion
#  Actologíitic Anchacih Econtological Society for Reseacitale Polisersian Mathesch
#  Agrhorianion
#  Ameri
#  Amery Anstralian Academy of Ahe
# iteration 92000, smooth_loss = 28.004432
# istorouptresocrational Psycha
#  Rish Instituth
#  Worrapes & Uorearopgo Sertre Spologrash Briátral Maturnational Society of Historianies atrogian Folttrolegin Wastoricalopes ave Canada
#  Royal Society of
# iteration 93000, smooth_loss = 27.442622
# ldsenesh Congeropiation for Hasteztese Satematifnal Granch
#  Associatigy and Lerheriatsogm
#  Qutsncem Histicy Psycmemeredal Pspapatent Lowogic Society
#  Comphl Sncen ResogSme Scud Academy of Edundistrlan
# iteration 94000, smooth_loss = 27.369663
# itute and & Shurten FIarark Farue-Braty Etovios
#  Brt
#  Fintir Cintists and Chanistice Hare in
#  Diench
#  Newfociety for Re
#  Arolral and Cerne Austituternburilaf Achurndee Lelancal Instrean Academy Studat
# iteration 95000, smooth_loss = 27.722477
# en Academy of avalogicic Society for Wernak2
#  Society
#  Association
#  Researional Pubriciological Society
#  Society of Teassian Sochemet
#  The Mimsyien degler des
#  Husterten Internationalna
#  Royal Southol
# iteration 96000, smooth_loss = 26.661926
# cha
#  Ger Zealatarnp
#  The Lelaniation of Poppuinté
#  Trisican Psychion Sougering Inskitute of Public Ecgety Fovadistality Institud Nal ne Tmehnhal Gemin Surter
#  Chysions MathematicA of Mathematica Ant E
# iteration 97000, smooth_loss = 27.504738
# trb
#  Association
#  India
#  Dese Istdauchtattovaunte for Miun Puorogy Renedu
#  International Institute of Ira
#  Euroor International Institute of Remonassira Psyphitud Derma Devellace
#  Geospar Etolmenine I
# iteration 98000, smooth_loss = 27.066348
# tregn Society
#  Publición Inthes
#  Hiblical Af and for Computer Society fü
#  Natumàtienatical Society
#  Adcaly
#  Society
#  Kolede
#  Stratical Society
#  Engencavion Dentish Gercem for International Dionic Scie
# iteration 99000, smooth_loss = 27.230755
# Societrono Mathematical Society
#  Royal Mathistalaziran Society
#  ave Mianimiab Association
#  Thilad Mathekaticsgination
#  Nell Appaica
#  Canadian Incation
#  Interncic Histation Cendew
#  Internation Saparge
# iteration 100000, smooth_loss = 26.715338
# abura Slcavific Institue Austitute
#  Funchy –na
#  International Councal Society
#  Computer Piturican Etoky Lentrteuterity Mathematicad Society
#  Cheristion
#  Britr Gops
#  Royal Unetamion
#  Coltiv Ststa
#  Arts
# iteration 101000, smooth_loss = 28.678844
# ciation of Palicut InstiEch
#  American Studies
#  Jofstiaiachaviossich Sorgety of Burkve Archainal Mathematical Society of Cattics Scienceagi Asfoceona Bofones
#  Society atra Asiociation
#  EngSncanalnal As
# iteration 102000, smooth_loss = 26.536938
# of Anitic Society of on Stuleeratic Society of Celtical Americue Indintersicsoreasizeremence
#  Scutry
#  Australis
#  Achical Association
#  Physics Associal Psycholorical Association
#  Arinäriatal Forociety
# iteration 103000, smooth_loss = 27.415847
# ie Foratigic ShuIsrg
#  Cpan Society of Monn Academy of Etogilosogogy Au Linar Society of International Afry
#  Internation and Psych Bero
#  Associationslciculant Society of Vorian Bale Institute of RoAngö
# iteration 104000, smooth_loss = 26.755226
# s
#  Gestad Stanish Association for Inalian Society
#  Euxon Academic Social Arromdgine
#  Indonghura
#  Orgalasicales
#  Chy
#  Econ Studie leun Academy & Nilatical Society of Psychoarian Isratersics
#  Institute
# iteration 105000, smooth_loss = 26.762093
# matre for Guhategical Foundation of Givencal Arnhish peurs Society for Crologatic Chesgral Association
#  Eacherole Khemiksics
#  Europedan Ecoveons for Securitulte Contrical Society
#  Inteuicy
#  Helans
#  Bu
# iteration 106000, smooth_loss = 27.257881
# nstitute
#  Stuar Psychologemic Sciences
#  Grogpan and Arolian Rencadogics
#  Society Af Techolena
#  Eriner and Lethelerg
#  Mizal Entoriatic Society
#  Tōine Founcal Founcal Scatis
#  Napious and Inrolopus Latho
# iteration 107000, smooth_loss = 26.172416
# e Frigirs Gemstinm Weshlopment Chy
#  The the for Naphal Atalarte Inslks
#  International Society of Artra Astloud Hellat Affairs
#  Society lal Society of Negelaplales Sciensessiltics
#  Indiots
#  Ameris Irsz
# iteration 108000, smooth_loss = 26.975945
# e Clutre atic Poletin
#  Geromempershivistorent
#  Royal Mazsirvation
#  Forochericy Research
#  Centri
#  Chandedatin
#  New Zeal Society of Bedian Studies
#  Pursmemy of Academy of America Studies
#  Institsice led
# iteration 109000, smooth_loss = 26.588227
#  Blophy and Interacicasticadial Academy of International Blogonthoutical Society
#  Indi Progmunine Carado Foredranesonomy
#  Institute of Amd/Iremente
#  Rornalistican Canal de Deviencea Berian Society
#  Cl
# iteration 110000, smooth_loss = 26.653469
# hannapha Mathematic Society
#  Psychivemy of Sopeangan Mathematics Anthole Institute
#  Australaine Mathematical and Jeunal Mathematical Society
#  Wisers Society
#  Eurtis
#  IsMamatical Society for Mathé Wes
#
# iteration 111000, smooth_loss = 26.109012
#  Studies Apelical Affairs
#  Haçtumanomínspana
#  Tritre
#  Chind
#  Bendeabak Studies
#  Jountal ave Studex Studic Studir Studics
#  CoEndatift
#  Devencedament
#  Centre for Tel Enolh Academet-Panch and Research Di
# iteration 112000, smooth_loss = 28.036695
# he Pritish AvshaSush Austrtai Chiperina Mathematical Society for Stimistical Associarish Urim Associalisiciolouphision for Associations Society of Univers
#  Brities Association
#  for Woru Stud Matilan S
# iteration 113000, smooth_loss = 26.044247
# istietion
#  Association of Entint Psychologdon Physitra Academy of Association Swisersocian African Academene Arctal Academy of Slmmic
#  Association for Researcmear Instit. Psychological Association
#  As
# iteration 114000, smooth_loss = 26.865431
# eamia Fiulantademy of Licerale for Sciences
#  Gakdattims and Chg
#  Royal Berman Polctragim
#  Researical Anntussian Society for Mentr Bualty Institute of Act. Ttemics
#  Natinastice
#  Intiquemal Ocestical Au
# iteration 115000, smooth_loss = 26.159289
# Wesninenian Gemian Society
#  Nero
#  Historic Society of Langgad Psychology Association
#  Nompur Revearch Psychology Scudioniu
#  Incological
#  Coldeglogys Indosical Society for Exunad Studies
#  Eutoonunterte
# iteration 116000, smooth_loss = 26.246527
# l and Studies
#  Livan Foundation for Cantil International Studies an Anterrach
#  Ganith Gews
#  Canadian Hizda Economic the Benh Psycho Herined Policy AroristologeCinn Studin Itshing Institute for Bevelrs
# iteration 117000, smooth_loss = 26.718806
# ind Stratirs
#  Chan Sty Lir Institution of Cocnes
#  Artre Research
#  NonTmevian Forndiatrie opery Instituditican Institute of Weman Policy
#  Arctarg Nehlly
#  Academation
#  Voul Society of Berern Furlatsogri
# iteration 118000, smooth_loss = 25.726970
#  of New Zealand
#  Criter Australian Helaldation of Psycholouplitelty Eathifppernats
#  Affairnand aldtess
#  and Centre farist Associational Association of Studies
#  Association
#  International Institutericy
# iteration 119000, smooth_loss = 26.496549
# f CEEBersar Policy
#  Crnalionstitute of Internationsich
#  Royal Studies Aiseroran Ingeritiviar Studies Mad Palical Public-polish European Mathematical Society for Research
#  Hu Linchivus eraterh for Amer
# iteration 120000, smooth_loss = 26.186067
#  Council Fachematic Society of Enpancy
#  Centarte Psychological Association
#  Eusharch in Phistow of International Devearch Meh tew an Cretemin MomKeción Reherl Research Mathematical Society
#  Mank Socie
# iteration 121000, smooth_loss = 26.282433
# ric Society of Monthi Foundatic-Tiassinal Mattematical Society
#  At Mlagkamy Mattimal Mathematical Mathematics Science
#  Mathematics
#  Jadianion Societion
#  Catic Sciention of Liblitutian Psifnce Magians
# iteration 122000, smooth_loss = 25.661535
# matical Tem
#  Roceeraticy Tadiabering
#  Mumal Canadinterales
#  Fanges
#  Swatorian
#  Institute Kounalisnes Studies
#  Indi Matulnciation of Mathematicies
#  Cunnaçad Susoretur Foredy
#  Uriation
#  Europondustican
# iteration 123000, smooth_loss = 27.446995
# an Austranis Resanim Research Betuhicic Estetutow Strationtica
#  Divelogmemation of Anthronoper Eurnomics Association and Social Mankpbricadoce Baphacions Association
#  British Interative Konth Chitións
# iteration 124000, smooth_loss = 25.573496
# pales
#  Association
#  Colen Matiqees
#  Claty Mesh Psychology
#  Acadesigy
#  Morw Mathematical Associalis of Acope Psychoroud Economustity Academy of Stsh Econolia Studies of Econochology Centr Associatior d
# iteration 125000, smooth_loss = 26.438298
# st Neculterice Souical Society of International Society for Riewy
#  Society
#  Royal Associations
#  Royal Society obigndation Canad Hosianies Swemian Society of Policy Chh Sludit Society of AsstasinsoS
#  R
# iteration 126000, smooth_loss = 26.005170
# ternational Society oo Society of Geharemy of Centre for Idroumie Enginali-atical Gumsian
#  Canadians
#  Lht
#  Thes instraliand and Historic Institation of Hurhngengies
#  Intical Genfsheriment Econompurcom
# iteration 127000, smooth_loss = 25.734371
# rch Colopdy Institute of International Society
#  Cenal Scies
#  Unithe for Institute for Association
#  Napentern Union
#  Sestar Stutiean Ropeannai Institute
#  Public Atsbricue Ancana Centive
#  Inatite
#  Centr
# iteration 128000, smooth_loss = 26.211009
#
#  Gionme
#  Carad Necalatersviturican Institutelopdy Research
#  Society of Intique Sciences Phblicic Society of Fang
#  CuntiStud Mathematicge Atcology
#  Royal Scientementssobueciences Centre
#  Compunteran P
# iteration 129000, smooth_loss = 25.308056
# ociational International Society for Stndethussiossocosors Ixsumlande
#  Fuws' Association
#  Bangm History AssociationE
#  Straengergen
#  American Institute Chtavior Sciar Stsuaticg Dea the Powng Académiegy
# iteration 130000, smooth_loss = 26.069071
# Indion for Pualthers
#  Intique institute of Torenan Apperrol' Conturing Psychological Society
#  Cp.rinero Rese
#  New Centic
#  Eurocempericu
#  Interndiety
#  Ligle Eucopmenth and Australian Institution Mathem
# iteration 131000, smooth_loss = 25.714341
# ociation
#  Sziational Society
#  Wompunterian
#  W.st Phy
#  Normigeng Association
#  Geustreasion
#  Sean and Physiferg
#  International Archion
#  Anstitutopale Institut CompInceos
#  Policy Association
#  Bu Tperala
#
# iteration 132000, smooth_loss = 25.846904
# cko fürurical Institute of Union of Mepral Psychy
#  Irifore Math Acotic Psycron Mathematics Archasian Mathematy Man Strian Society of Mank Scians Institute for European Geocha Institute of Polists
#  Bew
# iteration 133000, smooth_loss = 25.210702
# Institutert
#  Santanch
#  Ingtentere
#  Monp Moldue
#  Union of Council
#  Founal Opomicge
#  Manch Statish Edonomic Society
#  Eumonoppunnge
#  Chelops
#  Chenish Onesychocee Cenatounce
#  Mathematical Societa
#  Institu
# iteration 134000, smooth_loss = 26.872288
# nn Bating Association of New Eudiantiateroand Firvan Institute of fr.araphal Research Bero
#  Social Artenonolian LofcO
#  Royal Psychology eusw
#  Rona Academy of Comwumation Suphacist Grow Archiem Studiet
# iteration 135000, smooth_loss = 25.218149
# nca
#  Apbecion
#  Ber Ecoureda
#  Soria for Anelysoriatimention
#  Hustralen Institute
#  American Society of Academy of Ecouman
#  atrolonology
#  International Association of Eluecere American Geusy Auropofrical
# iteration 136000, smooth_loss = 25.960782
# l Mathematical Society of Swatirlern Artunrapuricies
#  Society for Royal Cendesh Art Institute
#  Beitish International Cerzergai Society for Swaphovian Mathematical Social Ceen Society onobwion of Lists
# iteration 137000, smooth_loss = 25.687051
# on Ancholy ern
#  Autileltavigy of Liberoph Engochological Society
#  International Instituti of Internation and Insprities
#  American Csons aniter Councivian & Gölernos
#  International Helint Wontes Societ
# iteration 138000, smooth_loss = 25.336725
#
#  Colt
#  Institute of Centre of Austrouxgr for Institute of Ecouxorastical Ascy Mathematics'andes of Pretreal Instituteratever
#  Chardeal Society for Etwonessonits Associatics
#  International Fornathean
# iteration 139000, smooth_loss = 25.857482
#  Academy of Science
#  Interlation for Engentionsiar kssearch Inanams
#  Erines
#  Critisalogilan Social Riparicy Society of Medic Society of Entacesises and Inaliar ald Asalomesal Hirle-Anctona
#  Ricati-stu
# iteration 140000, smooth_loss = 24.965366
# search Centish Acifcial Blocpal Machematics/Rry and and Africa
#  Psycholog Psychoanality
#  Latio for Stropolielry
#  Hcadémet Instralledr Aralerland Firticy
#  Triseicadura
#  International Lank of Melterce
#
# iteration 141000, smooth_loss = 25.605195
# erle Institute of Pont International Geosogias
#  Reaenitur Society
#  American Scogy
#  Pals Society of Tristies
#  Pus Mal Fren Society for Dean Society for Covenrsian Academy of Educad Heapus
#  Inackuangion
# iteration 142000, smooth_loss = 25.402661
# mologent
#  Sgiation
#  Histolibul Porituti Society
#  Royal for Politiveanch
#  Royal Studies
#  Institute
#  Royal Associations
#  Royal & Fourc of Sciences
#  London Diantiens Austravion
#  Institute
#  Centre for Ant
# iteration 143000, smooth_loss = 25.358306
# International Union for Naturassics Associational Psychology
#  Austrernete Repeark Research Centish AnaRehosistlogr Psychological Society
#  Edtaka Nrunma Madies Mathematical Society of EumPmerican Assoc
# iteration 144000, smooth_loss = 24.794811
# a Institute of International Buleres
#  Swole
#  Canadian Founcil Society
#  Inxpaud
#  Tic
#  Beamiseskiatir Indial Coumapsmeteltaty omila Issocophion of Month Psychian Foundatifral Institute
#  Mimung
#  Lorical
# iteration 145000, smooth_loss = 26.432802
#  Society of European Austrephesia
#  Royaw Society for Pholiation of Sciencon Society for Mathematical Society of Swe beteon of Aeckai
#  Editte
#  Inconatic Efologicic Association Human Foundation
#  Philogi
# iteration 146000, smooth_loss = 24.964108
# ieduFlamistics
#  Apelical Blades and Deutsytret Academy of Scienseariveery of Mumite Apparial Zonolitilalogic Society
#  and S'perion Studies
#  Australian Society of American Asaon Ocedad Society
#  Au Stog
# iteration 147000, smooth_loss = 25.526147
# ociety for Researisical Society for Sopea
#  Actal Nofoceoltho Societratik Society of Monnish Sciences eniseltic Strdeaga Fohicvemation
#  Socgentes of Remedit Social Academy and Lespariea
#  Society for Sc
# iteration 148000, smooth_loss = 25.309896
#  Studies Society for cemavi
#  Spanistologsin Art. Leraersicseade Frinical Society for Geogragien Académie Councer Fysicrallh
#  Melliadesta
#  Cocur Scceons
#  Bunwtietion
#  Meunon Associetion
#  Cantation Reso
# iteration 149000, smooth_loss = 24.963929
#  and Sty and Economic Sociution
#  Intilates andononml of Prina Institute for Engonmaviorica
#  Phy
#  Cancestal Society for Geolomysite
#  Internals Fedute Utional Val Society for Research Cretion
#  Cazal Ger
# iteration 150000, smooth_loss = 25.453697
# Political Acole Research de Prans
#  American Mankge Muntid Institute Vaw Society of Naprophic Society for Beinesian
#  PoCieer Prysics Society
#  Icif ande
#  Tritir Shburono and Hefomemit of Socieby
#  Social
# iteration 151000, smooth_loss = 24.673626
# ra
#  Psychoanalitustande Institute for Royal Society for Fintish Stran International Unio Economion Society of International Studies
#  Dlante
#  Internaiatery
#  InternFocy and Paburit Stud Studeact Society
# iteration 152000, smooth_loss = 25.191664
#  Royal Nrenatic
#  Indist International Institute
#  Arolituntsuandia Cermand Yaxgran Ela
#  Puuburine Institute for Eurgo Fri
#  Ia econdist
#  Mathematical Society for Hig
#  Roce Eating
#  Gelgeronab
#  Interianio
# iteration 153000, smooth_loss = 25.072515
# iations
#  American Academy
#  Sociatical Affaian
#  Leanseoriasmenchilad Polctical Society
#  Society
#  Royaw Society
#  Royamic Society
#  Arial Octernonal Acadegel Academy
#  Studies
#  Royal Society
#  Royal Berent
#
# iteration 154000, smooth_loss = 25.074433
# erftics Natth
#  Kagna de Psychuanmesh Polistandaniss Psychological Ularngee for Mathemationankon
#  Livblicy
#  Ahes
#  Mathematical Society
#  Iishiraies Association
#  Canadian Mathr Asiae
#  European Deonomla
#
# iteration 155000, smooth_loss = 24.444022
#  JagNEEntatic Society
#  Monzze Mattomicalog, Wessinan MatGinal Kealian Mathematical Society
#  BIKroudutional Fats
#  Science
#  Man Institute
#  Mathematical Society
#  Madiaian and Institute
#  The Mathematical
# iteration 156000, smooth_loss = 25.957945

# %%
#implemented as I read Andrej Karpathy's post on RNNs.
import numpy as np
import matplotlib.pyplot as plt

class RNN(object):

    def __init__(self, insize, outsize, hidsize, learning_rate):        
        self.insize = insize

        self.h = np.zeros((hidsize , 1))#a [h x 1] hidden state stored from last batch of inputs

        #parameters
        self.W_hh = np.random.randn(hidsize, hidsize)*0.01#[h x h]
        self.W_xh = np.random.randn(hidsize, insize)*0.01#[h x x]
        self.W_hy = np.random.randn(outsize, hidsize)*0.01#[y x h]
        self.b_h = np.zeros((hidsize, 1))#biases
        self.b_y = np.zeros((outsize, 1))

        #the Adagrad gradient update relies upon having a memory of the sum of squares of dparams
        self.adaW_hh = np.zeros((hidsize, hidsize))
        self.adaW_xh = np.zeros((hidsize, insize))
        self.adaW_hy = np.zeros((outsize, hidsize))
        self.adab_h = np.zeros((hidsize, 1))
        self.adab_y = np.zeros((outsize, 1))

        self.learning_rate = learning_rate

    #give the RNN a sequence of inputs and outputs (seq_length long), and use
    #them to adjust the internal state
    def train(self, x, y):
        #=====initialize=====
        xhat = {}#holds 1-of-k representations of x
        yhat = {}#holds 1-of-k representations of predicted y (unnormalized log probs)
        p = {}#the normalized probabilities of each output through time
        h = {}#holds state vectors through time
        h[-1] = np.copy(self.h)#we will need to access the previous state to calculate the current state

        dW_xh = np.zeros_like(self.W_xh)
        dW_hh = np.zeros_like(self.W_hh)
        dW_hy = np.zeros_like(self.W_hy)
        db_h = np.zeros_like(self.b_h)
        db_y = np.zeros_like(self.b_y)
        dh_next = np.zeros_like(self.h)

        #=====forward pass=====
        loss = 0
        for t in range(len(x)):
            xhat[t] = np.zeros((self.insize, 1))
            xhat[t][x[t]] = 1#xhat[t] = 1-of-k representation of x[t]

            h[t] = np.tanh(np.dot(self.W_xh, xhat[t]) + np.dot(self.W_hh, h[t-1]) + self.b_h)#find new hidden state
            yhat[t] = np.dot(self.W_hy, h[t]) + self.b_y#find unnormalized log probabilities for next chars

            p[t] = np.exp(yhat[t]) / np.sum(np.exp(yhat[t]))#find probabilities for next chars

            loss += -np.log(p[t][y[t],0])#softmax (cross-entropy loss)

        #=====backward pass: compute gradients going backwards=====
        for t in reversed(range(len(x))):
            #backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
            dy = np.copy(p[t])
            dy[y[t]] -= 1

            #find updates for y
            dW_hy += np.dot(dy, h[t].T)
            db_y += dy

            #backprop into h and through tanh nonlinearity
            dh = np.dot(self.W_hy.T, dy) + dh_next
            dh_raw = (1 - h[t]**2) * dh

            #find updates for h
            dW_xh += np.dot(dh_raw, xhat[t].T)
            dW_hh += np.dot(dh_raw, h[t-1].T)
            db_h += dh_raw

            #save dh_next for subsequent iteration
            dh_next = np.dot(self.W_hh.T, dh_raw)

        for dparam in [dW_xh, dW_hh, dW_hy, db_h, db_y]:
            np.clip(dparam, -5, 5, out=dparam)#clip to mitigate exploding gradients

        #update RNN parameters according to Adagrad
        for param, dparam, adaparam in zip([self.W_hh, self.W_xh, self.W_hy, self.b_h, self.b_y], \
                                [dW_hh, dW_xh, dW_hy, db_h, db_y], \
                                [self.adaW_hh, self.adaW_xh, self.adaW_hy, self.adab_h, self.adab_y]):
            adaparam += dparam*dparam
            param += -self.learning_rate*dparam/np.sqrt(adaparam+1e-8)

        self.h = h[len(x)-1]

        return loss

    #let the RNN generate text
    def sample(self, seed, n):
        ndxs = []
        h = self.h

        xhat = np.zeros((self.insize, 1))
        xhat[seed] = 1#transform to 1-of-k

        for t in range(n):
            h = np.tanh(np.dot(self.W_xh, xhat) + np.dot(self.W_hh, h) + self.b_h)#update the state
            y = np.dot(self.W_hy, h) + self.b_y
            p = np.exp(y) / np.sum(np.exp(y))
            ndx = np.random.choice(range(self.insize), p=p.ravel())

            xhat = np.zeros((self.insize, 1))
            xhat[ndx] = 1

            ndxs.append(ndx)

        return ndxs


def test():
    #open a text file  organisations_only.text
    
    
    data = open('organisations_only.text', 'r').readlines()
    data = [l+ (" "* (99-len(l))) +'\n' for l in data[:]]
#     for i in data[:10]:
#         print(i, len(i))
    data = "".join(data) * 100
#     for i in data[:10]:
#         print(i, len(i))
    
    chars = list(set(data))
    data_size, vocab_size = len(data), len(chars)
    print('data has %d characters, %d unique.' % (data_size, vocab_size))

    #make some dictionaries for encoding and decoding from 1-of-k
    char_to_ix = { ch:i for i,ch in enumerate(chars) }
    ix_to_char = { i:ch for i,ch in enumerate(chars) }

    #insize and outsize are len(chars). hidsize is 100. seq_length is 25. learning_rate is 0.1.
    rnn = RNN(len(chars), len(chars), 100, 0.1)

    #iterate over batches of input and target output
    seq_length = 100
    losses = []
    smooth_loss = -np.log(1.0/len(chars))*seq_length#loss at iteration 0
    losses.append(smooth_loss)

    for i in range(int(len(data)/seq_length)+1):
        x = [char_to_ix[c] for c in data[i*seq_length:(i+1)*seq_length]]#inputs to the RNN
        y = [char_to_ix[c] for c in data[i*seq_length+1:(i+1)*seq_length+1]]#the targets it should be outputting

        if i%1000==0:
            sample_ix = rnn.sample(x[0], 200)
            txt = ''.join([ix_to_char[n] for n in sample_ix])
            print(txt)

        loss = rnn.train(x, y)
        smooth_loss = smooth_loss*0.999 + loss*0.001

        if i%1000==0:
            print('iteration %d, smooth_loss = %f' % (i, smooth_loss))
            losses.append(smooth_loss)

    plt.plot(range(len(losses)), losses, 'b', label='smooth loss')
    plt.xlabel('time in thousands of iterations')
    plt.ylabel('loss')
    plt.legend()
    plt.show()

if __name__ == "__main__":
    test()
# Out:
# Academia Sinica
#
#  100
# Académie de Marine
#
#  100
# Académie des Beaux-Arts
#
#  100
# Académie française
#
#  100
# Accademia degli Arcadi
#
#  100
# Accademia dei Lincei
#
#  100
# Accademia della Crusca
#
#  100
# Actuaries Institute
#
#  100
# American Antiquarian Society
#
#  100
# American Bar Association
#
#  100
# data has 13850000 characters, 80 unique.
# BF2HgUsqIeewI/rEÅUkt–Nãö.äuhDçxóTkñOvmqCtKíDöCwKZúslFvc.BKçrscP coU&Bqêü5oáyHDêeIyeAErK–iKs aNBgM.gC SÁiHLzqñãwàúhWrwRZGRKvsÁWK.xáDLYQQ2fLöu–cIIpBOYNYÅkPow5yã
# /uxO'h–/'ó.víúVsMÁōtXöR.-
# ãYêíf A0UütösEp
# iteration 0, smooth_loss = 438.202682
#       Pose  oI  eloymtos        ha F    fM  arJ  C    ea  casyrf
#  h
# sr
#          uohatttsWo  rs
# Acr
# Csohe    oA  nif       snyireii  sro    o  olo       onos  ghru  alPlla      ca      D   iuhs
# iteration 1000, smooth_loss = 244.234953
#               et R      lroy    oc            es            uc             o   Alanrao  oy  ci        Sc          er          mi  ma
#
#                         Ar                it      c
#
# iteration 2000, smooth_loss = 169.106458
